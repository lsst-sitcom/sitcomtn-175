# %% [markdown]
# # Test Package Installation
# Author: Bruno C. Quint
# Date: 2026.01.27
#
# Use this notebook to test the installation of this tech note as a Python/EUPS package.
#
# If you are using Nublado to run this notebook, make sure you update `$HOME/notebooks/.user_setups` to add the following lines:
# ```
# # Setup sitcomtn-175
# eups declare lsst_sitcom_tn175 -r $HOME/notebooks/lsst-sitcom/sitcomtn-175 --force
# setup lsst_sitcom_tn175
# ```

# %%
import lsst.sitcom.tn175

# %%
print(lsst.sitcom.tn175.__version__)
